# %% [markdown]
# ### **IMPORT MODULES & LIBRARIES**

# %%
from doctest import master
from turtle import width
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from bokeh.plotting import figure, output_file, show, save, ColumnDataSource
from bokeh.models.tools import HoverTool
from bokeh.layouts import gridplot
from math import pi

# %% [markdown]
# ### **FEATURE 1** - READ TWO DATA FILES

# %%
specs = pd.read_excel('Specs.xlsx')
specs
# Out:
#     ID        Make       Model  Year  Front Legroom  Second Row Legroom  \
# 0    1       Honda      Accord  2022           42.3                40.4
# 1    2       Honda         CRV  2023           41.3                41.0
# 2    3      Toyota  Highlander  2022           42.0                41.0
# 3    4       Tesla     Model Y  2022           41.8                40.5
# 4    5    Infiniti        QX60  2023           42.1                37.7
# 5    6    Cadillac       Lyriq  2023           41.4                39.6
# 6    7       Honda       Pilot  2022           40.9                38.4
# 7    8       Lexus      RX 350  2022           44.1                38.0
# 8    9      Nissan      Maxima  2023           45.0                34.2
# 9   10       Acura         MDX  2022           41.6                38.5
# 10  11   Chevrolet    Suburban  2022           44.5                42.0
# 11  12   Chevrolet       Tahoe  2022           44.5                42.0
# 12  13       Dodge     Charger  2022           41.8                40.1
# 13  14         GMC       Yukon  2022           42.0                44.5
# 14  15       Honda     Odyssey  2022           40.9                40.9
# 15  16     Hyundai    Palisade  2022           44.1                42.4
# 16  17        Jeep    Cherokee  2022           41.3                38.2
# 17  18        Jeep    Wagoneer  2022           40.9                42.7
# 18  19        Jeep    Wrangler  2022           41.2                38.3
# 19  20         Kia         EV6  2022           42.4                39.0
# 20  21     Lincoln     Aviator  2022           43.0                39.0
# 21  22      Subaru      Ascent  2022           42.2                38.6
# 22  23      Subaru    Forester  2022           43.3                39.4
# 23  24       Tesla     Model 3  2022           42.7                35.2
# 24  25       Tesla     Model S  2022           42.4                35.5
# 25  26       Tesla     Model X  2022           41.1                38.7
# 26  27      Toyota        RAV4  2022           41.0                37.8
# 27  28      Toyota     Sequoia  2022           42.5                40.9
# 28  29  Volkswagen       Atlas  2022           41.7                37.6
#
#     Combined Gas  Highway Gas  City Gas    MSRP  Car Type Cylinders Trim  \
# 0             32           35        29   30470       Gas         4  FWD
# 1             37           34        40   36000    Hybrid         4  AWD
# 2             35           35        35   43000    Hybrid         6  AWD
# 3            125          117       131   68000  Electric  Electric  AWD
# 4             22           25        20   60000       Gas         6  AWD
# 5             87           82        92   64000  Electric  Electric  AWD
# 6             22           19        26   51000       Gas         6  AWD
# 7             22           26        19   55000       Gas         6  AWD
# 8             24           30        20   43300       Gas         6  AWD
# 9             21           25        19   54900       Gas         6  AWD
# 10            17           20        15   57800       Gas         8  AWD
# 11            17           20        15   58100       Gas         8  AWD
# 12            21           27        18   38275       Gas         6  AWD
# 13            17           20        15   54600       Gas         8  AWD
# 14            22           28        19   48770       Gas         6  FWD
# 15            21           24        19   35300       Gas         6  AWD
# 16            22           26        19   46645       Gas         6  AWD
# 17            18           22        16   68995       Gas         8  AWD
# 18            19           23        17   39240       Gas         6  AWD
# 19           105           94       116   51400  Electric  Electric  AWD
# 20            20           24        17   54285       Gas         6  AWD
# 21            23           27        21   35295       Gas         4  AWD
# 22            29           33        26   32575       Gas         4  AWD
# 23           113          107       118   62990  Electric  Electric  AWD
# 24           120          115       124  104990  Electric  Electric  AWD
# 25           102           97       107  120990  Electric  Electric  AWD
# 26            29           33        27   32735       Gas         4  AWD
# 27            14           17        13   63830       Gas         8  AWD
# 28            19           23        17   45855       Gas         6  AWD
#
#    Gwen's Choice                    Image
# 0              Y      .\images\Accord.jpg
# 1              Y         .\images\CRV.jpg
# 2              Y  .\images\Highlander.jpg
# 3              Y      .\images\ModelY.jpg
# 4              Y        .\images\QX60.jpg
# 5              Y       .\images\Lyriq.jpg
# 6              Y       .\images\Pilot.jpg
# 7              Y       .\images\RX350.jpg
# 8              N                      NaN
# 9              N                      NaN
# 10             N                      NaN
# 11             N                      NaN
# 12             N                      NaN
# 13             N                      NaN
# 14             N                      NaN
# 15             N                      NaN
# 16             N                      NaN
# 17             N                      NaN
# 18             N                      NaN
# 19             N                      NaN
# 20             N                      NaN
# 21             N                      NaN
# 22             N                      NaN
# 23             N                      NaN
# 24             N                      NaN
# 25             N                      NaN
# 26             N                      NaN
# 27             N                      NaN
# 28             N                      NaN

# %%
cars = pd.read_csv('Cars_22-23.csv')
cars
# Out:
#      year      make  model body_styles
# 0    2022     Acura    ILX   ["Sedan"]
# 1    2022     Acura    MDX     ["SUV"]
# 2    2022     Acura    NSX   ["Coupe"]
# 3    2022     Acura    RDX     ["SUV"]
# 4    2022     Acura    TLX   ["Sedan"]
# ..    ...       ...    ...         ...
# 475  2022     Volvo   XC60     ["SUV"]
# 476  2022     Volvo   XC90     ["SUV"]
# 477  2023  Cadillac  LYRIQ     ["SUV"]
# 478  2023     Honda   CR-V     ["SUV"]
# 479  2023  INFINITI   QX60     ["SUV"]
#
# [480 rows x 4 columns]

# %% [markdown]
# ### **FEATURE 2** - CLEAN YOUR DATA AND PERFORM A PANDAS MERGE WITH YOUR TWO DATA SETS, THEN CALCULATE SOME NEW VALUES BASED ON THE NEW DATA SET

# %% [markdown]
# ##### DATA CLEANING

# %%
#Converting year from int to string
cars['year'] = cars['year'].astype(str)
specs['Year'] = specs['Year'].astype(str)

# %%
#Capitalize car makes
cars['make'] = cars['make'].str.capitalize()
cars
# Out:
#      year      make  model body_styles
# 0    2022     Acura    ILX   ["Sedan"]
# 1    2022     Acura    MDX     ["SUV"]
# 2    2022     Acura    NSX   ["Coupe"]
# 3    2022     Acura    RDX     ["SUV"]
# 4    2022     Acura    TLX   ["Sedan"]
# ..    ...       ...    ...         ...
# 475  2022     Volvo   XC60     ["SUV"]
# 476  2022     Volvo   XC90     ["SUV"]
# 477  2023  Cadillac  LYRIQ     ["SUV"]
# 478  2023     Honda   CR-V     ["SUV"]
# 479  2023  Infiniti   QX60     ["SUV"]
#
# [480 rows x 4 columns]

# %%
#Correct car models misspellings
cars['model'].replace(to_replace="LYRIQ",
           value="Lyriq", inplace=True)

cars['model'].replace(to_replace="CR-V",
           value="CRV", inplace=True)

cars['model'].replace(to_replace="RX",
           value="RX 350", inplace=True)
cars
# Out:
#      year      make  model body_styles
# 0    2022     Acura    ILX   ["Sedan"]
# 1    2022     Acura    MDX     ["SUV"]
# 2    2022     Acura    NSX   ["Coupe"]
# 3    2022     Acura    RDX     ["SUV"]
# 4    2022     Acura    TLX   ["Sedan"]
# ..    ...       ...    ...         ...
# 475  2022     Volvo   XC60     ["SUV"]
# 476  2022     Volvo   XC90     ["SUV"]
# 477  2023  Cadillac  Lyriq     ["SUV"]
# 478  2023     Honda    CRV     ["SUV"]
# 479  2023  Infiniti   QX60     ["SUV"]
#
# [480 rows x 4 columns]

# %% [markdown]
# ##### MERGE & DATA CLEANING

# %%
#Creating unique ID for join/merging on cars table, then removing trailing and leading empty spaces
cars["Year_Make_Model"] = cars[['year', 'make', 'model']].agg('_'.join, axis=1)
cars["Year_Make_Model"] = cars["Year_Make_Model"].str.strip()
cars
# Out:
#      year      make  model body_styles      Year_Make_Model
# 0    2022     Acura    ILX   ["Sedan"]       2022_Acura_ILX
# 1    2022     Acura    MDX     ["SUV"]       2022_Acura_MDX
# 2    2022     Acura    NSX   ["Coupe"]       2022_Acura_NSX
# 3    2022     Acura    RDX     ["SUV"]       2022_Acura_RDX
# 4    2022     Acura    TLX   ["Sedan"]       2022_Acura_TLX
# ..    ...       ...    ...         ...                  ...
# 475  2022     Volvo   XC60     ["SUV"]      2022_Volvo_XC60
# 476  2022     Volvo   XC90     ["SUV"]      2022_Volvo_XC90
# 477  2023  Cadillac  Lyriq     ["SUV"]  2023_Cadillac_Lyriq
# 478  2023     Honda    CRV     ["SUV"]       2023_Honda_CRV
# 479  2023  Infiniti   QX60     ["SUV"]   2023_Infiniti_QX60
#
# [480 rows x 5 columns]

# %%
#Creating unique ID for join/merging on specs table, then removing trailing and leading empty spaces
specs["Year_Make_Model"] = specs[['Year', 'Make', 'Model']].agg('_'.join, axis=1)
specs["Year_Make_Model"] = specs["Year_Make_Model"].str.strip()
specs
# Out:
#     ID        Make       Model  Year  Front Legroom  Second Row Legroom  \
# 0    1       Honda      Accord  2022           42.3                40.4
# 1    2       Honda         CRV  2023           41.3                41.0
# 2    3      Toyota  Highlander  2022           42.0                41.0
# 3    4       Tesla     Model Y  2022           41.8                40.5
# 4    5    Infiniti        QX60  2023           42.1                37.7
# 5    6    Cadillac       Lyriq  2023           41.4                39.6
# 6    7       Honda       Pilot  2022           40.9                38.4
# 7    8       Lexus      RX 350  2022           44.1                38.0
# 8    9      Nissan      Maxima  2023           45.0                34.2
# 9   10       Acura         MDX  2022           41.6                38.5
# 10  11   Chevrolet    Suburban  2022           44.5                42.0
# 11  12   Chevrolet       Tahoe  2022           44.5                42.0
# 12  13       Dodge     Charger  2022           41.8                40.1
# 13  14         GMC       Yukon  2022           42.0                44.5
# 14  15       Honda     Odyssey  2022           40.9                40.9
# 15  16     Hyundai    Palisade  2022           44.1                42.4
# 16  17        Jeep    Cherokee  2022           41.3                38.2
# 17  18        Jeep    Wagoneer  2022           40.9                42.7
# 18  19        Jeep    Wrangler  2022           41.2                38.3
# 19  20         Kia         EV6  2022           42.4                39.0
# 20  21     Lincoln     Aviator  2022           43.0                39.0
# 21  22      Subaru      Ascent  2022           42.2                38.6
# 22  23      Subaru    Forester  2022           43.3                39.4
# 23  24       Tesla     Model 3  2022           42.7                35.2
# 24  25       Tesla     Model S  2022           42.4                35.5
# 25  26       Tesla     Model X  2022           41.1                38.7
# 26  27      Toyota        RAV4  2022           41.0                37.8
# 27  28      Toyota     Sequoia  2022           42.5                40.9
# 28  29  Volkswagen       Atlas  2022           41.7                37.6
#
#     Combined Gas  Highway Gas  City Gas    MSRP  Car Type Cylinders Trim  \
# 0             32           35        29   30470       Gas         4  FWD
# 1             37           34        40   36000    Hybrid         4  AWD
# 2             35           35        35   43000    Hybrid         6  AWD
# 3            125          117       131   68000  Electric  Electric  AWD
# 4             22           25        20   60000       Gas         6  AWD
# 5             87           82        92   64000  Electric  Electric  AWD
# 6             22           19        26   51000       Gas         6  AWD
# 7             22           26        19   55000       Gas         6  AWD
# 8             24           30        20   43300       Gas         6  AWD
# 9             21           25        19   54900       Gas         6  AWD
# 10            17           20        15   57800       Gas         8  AWD
# 11            17           20        15   58100       Gas         8  AWD
# 12            21           27        18   38275       Gas         6  AWD
# 13            17           20        15   54600       Gas         8  AWD
# 14            22           28        19   48770       Gas         6  FWD
# 15            21           24        19   35300       Gas         6  AWD
# 16            22           26        19   46645       Gas         6  AWD
# 17            18           22        16   68995       Gas         8  AWD
# 18            19           23        17   39240       Gas         6  AWD
# 19           105           94       116   51400  Electric  Electric  AWD
# 20            20           24        17   54285       Gas         6  AWD
# 21            23           27        21   35295       Gas         4  AWD
# 22            29           33        26   32575       Gas         4  AWD
# 23           113          107       118   62990  Electric  Electric  AWD
# 24           120          115       124  104990  Electric  Electric  AWD
# 25           102           97       107  120990  Electric  Electric  AWD
# 26            29           33        27   32735       Gas         4  AWD
# 27            14           17        13   63830       Gas         8  AWD
# 28            19           23        17   45855       Gas         6  AWD
#
#    Gwen's Choice                    Image          Year_Make_Model
# 0              Y      .\images\Accord.jpg        2022_Honda_Accord
# 1              Y         .\images\CRV.jpg           2023_Honda_CRV
# 2              Y  .\images\Highlander.jpg   2022_Toyota_Highlander
# 3              Y      .\images\ModelY.jpg       2022_Tesla_Model Y
# 4              Y        .\images\QX60.jpg       2023_Infiniti_QX60
# 5              Y       .\images\Lyriq.jpg      2023_Cadillac_Lyriq
# 6              Y       .\images\Pilot.jpg         2022_Honda_Pilot
# 7              Y       .\images\RX350.jpg        2022_Lexus_RX 350
# 8              N                      NaN       2023_Nissan_Maxima
# 9              N                      NaN           2022_Acura_MDX
# 10             N                      NaN  2022_Chevrolet_Suburban
# 11             N                      NaN     2022_Chevrolet_Tahoe
# 12             N                      NaN       2022_Dodge_Charger
# 13             N                      NaN           2022_GMC_Yukon
# 14             N                      NaN       2022_Honda_Odyssey
# 15             N                      NaN    2022_Hyundai_Palisade
# 16             N                      NaN       2022_Jeep_Cherokee
# 17             N                      NaN       2022_Jeep_Wagoneer
# 18             N                      NaN       2022_Jeep_Wrangler
# 19             N                      NaN             2022_Kia_EV6
# 20             N                      NaN     2022_Lincoln_Aviator
# 21             N                      NaN       2022_Subaru_Ascent
# 22             N                      NaN     2022_Subaru_Forester
# 23             N                      NaN       2022_Tesla_Model 3
# 24             N                      NaN       2022_Tesla_Model S
# 25             N                      NaN       2022_Tesla_Model X
# 26             N                      NaN         2022_Toyota_RAV4
# 27             N                      NaN      2022_Toyota_Sequoia
# 28             N                      NaN    2022_Volkswagen_Atlas

# %%
#Joining cars and specs based on year, make and model
master_df=pd.merge(cars,specs, on='Year_Make_Model', how='left')
master_df
# Out:
#      year      make  model body_styles      Year_Make_Model    ID      Make  \
# 0    2022     Acura    ILX   ["Sedan"]       2022_Acura_ILX   NaN       NaN
# 1    2022     Acura    MDX     ["SUV"]       2022_Acura_MDX  10.0     Acura
# 2    2022     Acura    NSX   ["Coupe"]       2022_Acura_NSX   NaN       NaN
# 3    2022     Acura    RDX     ["SUV"]       2022_Acura_RDX   NaN       NaN
# 4    2022     Acura    TLX   ["Sedan"]       2022_Acura_TLX   NaN       NaN
# ..    ...       ...    ...         ...                  ...   ...       ...
# 475  2022     Volvo   XC60     ["SUV"]      2022_Volvo_XC60   NaN       NaN
# 476  2022     Volvo   XC90     ["SUV"]      2022_Volvo_XC90   NaN       NaN
# 477  2023  Cadillac  Lyriq     ["SUV"]  2023_Cadillac_Lyriq   6.0  Cadillac
# 478  2023     Honda    CRV     ["SUV"]       2023_Honda_CRV   2.0     Honda
# 479  2023  Infiniti   QX60     ["SUV"]   2023_Infiniti_QX60   5.0  Infiniti
#
#      Model  Year  Front Legroom  Second Row Legroom  Combined Gas  \
# 0      NaN   NaN            NaN                 NaN           NaN
# 1      MDX  2022           41.6                38.5          21.0
# 2      NaN   NaN            NaN                 NaN           NaN
# 3      NaN   NaN            NaN                 NaN           NaN
# 4      NaN   NaN            NaN                 NaN           NaN
# ..     ...   ...            ...                 ...           ...
# 475    NaN   NaN            NaN                 NaN           NaN
# 476    NaN   NaN            NaN                 NaN           NaN
# 477  Lyriq  2023           41.4                39.6          87.0
# 478    CRV  2023           41.3                41.0          37.0
# 479   QX60  2023           42.1                37.7          22.0
#
#      Highway Gas  City Gas     MSRP  Car Type Cylinders Trim Gwen's Choice  \
# 0            NaN       NaN      NaN       NaN       NaN  NaN           NaN
# 1           25.0      19.0  54900.0       Gas         6  AWD             N
# 2            NaN       NaN      NaN       NaN       NaN  NaN           NaN
# 3            NaN       NaN      NaN       NaN       NaN  NaN           NaN
# 4            NaN       NaN      NaN       NaN       NaN  NaN           NaN
# ..           ...       ...      ...       ...       ...  ...           ...
# 475          NaN       NaN      NaN       NaN       NaN  NaN           NaN
# 476          NaN       NaN      NaN       NaN       NaN  NaN           NaN
# 477         82.0      92.0  64000.0  Electric  Electric  AWD             Y
# 478         34.0      40.0  36000.0    Hybrid         4  AWD             Y
# 479         25.0      20.0  60000.0       Gas         6  AWD             Y
#
#                   Image
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
# ..                  ...
# 475                 NaN
# 476                 NaN
# 477  .\images\Lyriq.jpg
# 478    .\images\CRV.jpg
# 479   .\images\QX60.jpg
#
# [480 rows x 20 columns]

# %% [markdown]
# ##### MORE DATA CLEANING ON MERGED DATASET

# %%
#Dropping and renaming columns
master_df.drop(columns=['Year', 'Make', 'Model', 'ID'], inplace=True)
master_df.rename(columns={'year':'Year', 'make':'Make', 'model':'Model'}, inplace=True)
master_df.rename(columns={'body_styles':'Body Styles'}, inplace=True)
master_df
# Out:
#      Year      Make  Model Body Styles      Year_Make_Model  Front Legroom  \
# 0    2022     Acura    ILX   ["Sedan"]       2022_Acura_ILX            NaN
# 1    2022     Acura    MDX     ["SUV"]       2022_Acura_MDX           41.6
# 2    2022     Acura    NSX   ["Coupe"]       2022_Acura_NSX            NaN
# 3    2022     Acura    RDX     ["SUV"]       2022_Acura_RDX            NaN
# 4    2022     Acura    TLX   ["Sedan"]       2022_Acura_TLX            NaN
# ..    ...       ...    ...         ...                  ...            ...
# 475  2022     Volvo   XC60     ["SUV"]      2022_Volvo_XC60            NaN
# 476  2022     Volvo   XC90     ["SUV"]      2022_Volvo_XC90            NaN
# 477  2023  Cadillac  Lyriq     ["SUV"]  2023_Cadillac_Lyriq           41.4
# 478  2023     Honda    CRV     ["SUV"]       2023_Honda_CRV           41.3
# 479  2023  Infiniti   QX60     ["SUV"]   2023_Infiniti_QX60           42.1
#
#      Second Row Legroom  Combined Gas  Highway Gas  City Gas     MSRP  \
# 0                   NaN           NaN          NaN       NaN      NaN
# 1                  38.5          21.0         25.0      19.0  54900.0
# 2                   NaN           NaN          NaN       NaN      NaN
# 3                   NaN           NaN          NaN       NaN      NaN
# 4                   NaN           NaN          NaN       NaN      NaN
# ..                  ...           ...          ...       ...      ...
# 475                 NaN           NaN          NaN       NaN      NaN
# 476                 NaN           NaN          NaN       NaN      NaN
# 477                39.6          87.0         82.0      92.0  64000.0
# 478                41.0          37.0         34.0      40.0  36000.0
# 479                37.7          22.0         25.0      20.0  60000.0
#
#      Car Type Cylinders Trim Gwen's Choice               Image
# 0         NaN       NaN  NaN           NaN                 NaN
# 1         Gas         6  AWD             N                 NaN
# 2         NaN       NaN  NaN           NaN                 NaN
# 3         NaN       NaN  NaN           NaN                 NaN
# 4         NaN       NaN  NaN           NaN                 NaN
# ..        ...       ...  ...           ...                 ...
# 475       NaN       NaN  NaN           NaN                 NaN
# 476       NaN       NaN  NaN           NaN                 NaN
# 477  Electric  Electric  AWD             Y  .\images\Lyriq.jpg
# 478    Hybrid         4  AWD             Y    .\images\CRV.jpg
# 479       Gas         6  AWD             Y   .\images\QX60.jpg
#
# [480 rows x 16 columns]

# %%
#Calculating new column
master_df['Combined_Legroom'] = master_df['Front Legroom'] + master_df['Second Row Legroom']
master_df
# Out:
#      Year      Make  Model Body Styles      Year_Make_Model  Front Legroom  \
# 0    2022     Acura    ILX   ["Sedan"]       2022_Acura_ILX            NaN
# 1    2022     Acura    MDX     ["SUV"]       2022_Acura_MDX           41.6
# 2    2022     Acura    NSX   ["Coupe"]       2022_Acura_NSX            NaN
# 3    2022     Acura    RDX     ["SUV"]       2022_Acura_RDX            NaN
# 4    2022     Acura    TLX   ["Sedan"]       2022_Acura_TLX            NaN
# ..    ...       ...    ...         ...                  ...            ...
# 475  2022     Volvo   XC60     ["SUV"]      2022_Volvo_XC60            NaN
# 476  2022     Volvo   XC90     ["SUV"]      2022_Volvo_XC90            NaN
# 477  2023  Cadillac  Lyriq     ["SUV"]  2023_Cadillac_Lyriq           41.4
# 478  2023     Honda    CRV     ["SUV"]       2023_Honda_CRV           41.3
# 479  2023  Infiniti   QX60     ["SUV"]   2023_Infiniti_QX60           42.1
#
#      Second Row Legroom  Combined Gas  Highway Gas  City Gas     MSRP  \
# 0                   NaN           NaN          NaN       NaN      NaN
# 1                  38.5          21.0         25.0      19.0  54900.0
# 2                   NaN           NaN          NaN       NaN      NaN
# 3                   NaN           NaN          NaN       NaN      NaN
# 4                   NaN           NaN          NaN       NaN      NaN
# ..                  ...           ...          ...       ...      ...
# 475                 NaN           NaN          NaN       NaN      NaN
# 476                 NaN           NaN          NaN       NaN      NaN
# 477                39.6          87.0         82.0      92.0  64000.0
# 478                41.0          37.0         34.0      40.0  36000.0
# 479                37.7          22.0         25.0      20.0  60000.0
#
#      Car Type Cylinders Trim Gwen's Choice               Image  \
# 0         NaN       NaN  NaN           NaN                 NaN
# 1         Gas         6  AWD             N                 NaN
# 2         NaN       NaN  NaN           NaN                 NaN
# 3         NaN       NaN  NaN           NaN                 NaN
# 4         NaN       NaN  NaN           NaN                 NaN
# ..        ...       ...  ...           ...                 ...
# 475       NaN       NaN  NaN           NaN                 NaN
# 476       NaN       NaN  NaN           NaN                 NaN
# 477  Electric  Electric  AWD             Y  .\images\Lyriq.jpg
# 478    Hybrid         4  AWD             Y    .\images\CRV.jpg
# 479       Gas         6  AWD             Y   .\images\QX60.jpg
#
#      Combined_Legroom
# 0                 NaN
# 1                80.1
# 2                 NaN
# 3                 NaN
# 4                 NaN
# ..                ...
# 475               NaN
# 476               NaN
# 477              81.0
# 478              82.3
# 479              79.8
#
# [480 rows x 17 columns]

# %%
#Calculating the number of models for each maker in 2022
cars_2022_df = master_df[master_df["Year"] == "2022"]
master_2022_cars_df = cars_2022_df['Make'].value_counts().rename_axis('Make').reset_index(name='Number of Models')
master_2022_cars_df
# Out:
#              Make  Number of Models
# 0   Mercedes-benz                43
# 1            Ford                39
# 2            Audi                38
# 3       Chevrolet                31
# 4          Toyota                29
# 5             Bmw                24
# 6             Gmc                23
# 7         Hyundai                22
# 8          Nissan                17
# 9             Kia                16
# 10            Ram                14
# 11          Honda                12
# 12           Jeep                12
# 13     Volkswagen                11
# 14        Porsche                10
# 15          Lexus                10
# 16          Volvo                 9
# 17         Subaru                 8
# 18     Land rover                 8
# 19        Ferrari                 8
# 20        Genesis                 7
# 21          Mazda                 7
# 22       Cadillac                 7
# 23     Mitsubishi                 6
# 24       Infiniti                 6
# 25          Tesla                 5
# 26           Mini                 5
# 27        Lincoln                 5
# 28         Jaguar                 5
# 29          Acura                 5
# 30       Maserati                 4
# 31       Chrysler                 4
# 32          Buick                 4
# 33   Aston martin                 4
# 34          Dodge                 3
# 35    Lamborghini                 3
# 36    Rolls-royce                 3
# 37        Bentley                 3
# 38     Alfa romeo                 2
# 39         Rivian                 2
# 40          Lucid                 1
# 41       Polestar                 1
# 42           Fiat                 1

# %%
#Filtering to only see cars we are considering purchasing
my_choices_df = master_df[master_df["Gwen's Choice"] == "Y"]
my_choices_df
# Out:
#      Year      Make       Model Body Styles         Year_Make_Model  \
# 203  2022     Honda      Accord   ["Sedan"]       2022_Honda_Accord
# 213  2022     Honda       Pilot     ["SUV"]        2022_Honda_Pilot
# 295  2022     Lexus      RX 350     ["SUV"]       2022_Lexus_RX 350
# 427  2022     Tesla     Model Y     ["SUV"]      2022_Tesla_Model Y
# 441  2022    Toyota  Highlander     ["SUV"]  2022_Toyota_Highlander
# 477  2023  Cadillac       Lyriq     ["SUV"]     2023_Cadillac_Lyriq
# 478  2023     Honda         CRV     ["SUV"]          2023_Honda_CRV
# 479  2023  Infiniti        QX60     ["SUV"]      2023_Infiniti_QX60
#
#      Front Legroom  Second Row Legroom  Combined Gas  Highway Gas  City Gas  \
# 203           42.3                40.4          32.0         35.0      29.0
# 213           40.9                38.4          22.0         19.0      26.0
# 295           44.1                38.0          22.0         26.0      19.0
# 427           41.8                40.5         125.0        117.0     131.0
# 441           42.0                41.0          35.0         35.0      35.0
# 477           41.4                39.6          87.0         82.0      92.0
# 478           41.3                41.0          37.0         34.0      40.0
# 479           42.1                37.7          22.0         25.0      20.0
#
#         MSRP  Car Type Cylinders Trim Gwen's Choice                    Image  \
# 203  30470.0       Gas         4  FWD             Y      .\images\Accord.jpg
# 213  51000.0       Gas         6  AWD             Y       .\images\Pilot.jpg
# 295  55000.0       Gas         6  AWD             Y       .\images\RX350.jpg
# 427  68000.0  Electric  Electric  AWD             Y      .\images\ModelY.jpg
# 441  43000.0    Hybrid         6  AWD             Y  .\images\Highlander.jpg
# 477  64000.0  Electric  Electric  AWD             Y       .\images\Lyriq.jpg
# 478  36000.0    Hybrid         4  AWD             Y         .\images\CRV.jpg
# 479  60000.0       Gas         6  AWD             Y        .\images\QX60.jpg
#
#      Combined_Legroom
# 203              82.7
# 213              79.3
# 295              82.1
# 427              82.3
# 441              83.0
# 477              81.0
# 478              82.3
# 479              79.8

# %% [markdown]
# ### **FEATURE 3** - MAKE A VISUALIZATION WITH BOKEH

# %%
#Sorting my choices based on different sort values, this will be used to sort my plots.
my_choices_Legroom_df = my_choices_df.sort_values(by='Combined_Legroom')
my_choices_MSRP_df = my_choices_df.sort_values(by='MSRP')
my_choices_MPG_df = my_choices_df.sort_values(by='Combined Gas')

# %%
#Create ColumnDataSource from data frame, this will allow me to bring in column names in my plots.
source1 = ColumnDataSource(my_choices_MSRP_df)
source2 = ColumnDataSource(master_2022_cars_df)
source3 = ColumnDataSource(my_choices_Legroom_df)
source4 = ColumnDataSource(my_choices_MPG_df)

# %%
#Creating an output file, where the bokeh plots will be outputted to.
output_file('index.html')

#Car list
car_list1 = source1.data['Model'].tolist()
car_list2 = source2.data['Make'].tolist()
car_list3 = source3.data['Model'].tolist()
car_list4 = source4.data['Model'].tolist()

# %%
#Add plots. Creating 4 different plots to be in my bokeh grid.

#Plot #1
plot1 = figure(
       x_range=car_list1,
       plot_width=800,
       plot_height=600,
       title='Cars MSRP',
       y_axis_label='MSRP'
)

#Render glyph
plot1.vbar(
    x='Model',
    top='MSRP',
    bottom=0,
    width=0.4,
    color='lightsteelblue',
    fill_alpha = 0.7,
    source=source1
)
plot1.y_range.start = 0
plot1.xgrid.grid_line_color = None

# %%
#Plot #2
plot2 = figure(
       x_range=car_list2,
       plot_width=800,
       plot_height=600,
       title='Number of Models per Maker',
       y_axis_label='Number of Models'
)


#Render glyph
plot2.vbar(
    x='Make',
    top='Number of Models',
    bottom=0,
    width=0.4,
    color='lightsalmon',
    fill_alpha=0.7,
    source=source2
)
plot2.xaxis.major_label_orientation = pi/4
plot2.y_range.start = 0
plot2.xgrid.grid_line_color = None

# %%
#Plot 3
plot3 = figure(
       y_range=car_list3,
       #plot_width=800,
       #plot_height=600,
       title='Cars Legrooom',
       x_axis_label='Legroom (inches)'
)

#Render glyph
plot3.hbar(
    y='Model',
    right='Combined_Legroom',
    left=0,
    height=0.4,
    color='salmon',
    fill_alpha=0.9,
    source=source3
)
plot3.x_range.start = 0
plot3.ygrid.grid_line_color = None

# %%
#Plot #4
plot4 = figure(
       x_range=car_list4,
       plot_width=800,
       plot_height=600,
       title='Cars Combined Gas Mileage',
       y_axis_label='Combined Gas Mileage (mpg)'
)

#Render glyph
plot4.vbar(
    x='Model',
    top='Combined Gas',
    bottom=0,
    width=0.4,
    color='steelblue',
    fill_alpha=0.9,
    source=source4
)
plot4.y_range.start = 0
plot4.xgrid.grid_line_color = None

# %%
#Add Tooltips. These tooltips will pop up an image of the car when a bar in the plot is hovered over.
hover = HoverTool()
hover.tooltips = """
    <div>
        <h3>@Make @Model</h3>
        <div><strong>Price: </strong>$@MSRP</div>
        <div><strong>Legroom: </strong>@Combined_Legroom in</div>
        <div><img src="@Image" alt="" width="200" /></div>
    </div>
"""

plot1.add_tools(hover)
plot3.add_tools(hover)
plot4.add_tools(hover)

# %%
#Make a grid
grid = gridplot([[plot1, plot2], [plot3, plot4]], width=700, height=300)

# %%
#Show and save grid
save(grid)

print("To view the visuals, open the index.html file in your favorite internet browser (ie. Google Chrome)")
# Out:
# To view the visuals, open the index.html file in your favorite internet browser (ie. Google Chrome)
